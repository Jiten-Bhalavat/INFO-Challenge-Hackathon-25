# %% [markdown]
# ## Requirements

# %%
# %pip install langchain_openai
# %pip install langchain_core
# %pip install langchain_community
# %pip install langchain_experimental

# %%
from langchain_openai.chat_models import ChatOpenAI
import os

openai_key = os.environ.get("OPENAI_API")
gpt4o = ChatOpenAI(temperature=0.0, model="gpt-4o-mini", openai_api_key=os.getenv("OPENAI_API_KEY"))

# %%
import pandas as pd

def extract_metadata(df):
    metadata = {}

    # Number of columns
    metadata['Number of Columns'] = df.shape[1]

    # Column names
    metadata['Schema'] = df.columns.tolist()

    # Data types of each column
    metadata['Data Types'] = str(df.dtypes)

    # Store multiple rows in the sample (default: first 5 rows)
    metadata['Sample'] = df.head(100).to_dict(orient="records")

    return metadata

# %%
import pandas as pd
import pandas as pd

df = pd.read_csv("try1.csv", encoding="latin-1")  # or encoding="ISO-8859-1"
metadata = extract_metadata(df)

# %%
print(metadata)
# Out:
# {'Number of Columns': 13, 'Schema': ['ID', 'Agency', 'Record Group', 'GAL LOOKUP - Display name', 'GAL LOOKUP - Email Address', 'Alias', 'Name', 'Role', 'Beginning Date', 'Ending Date', 'Currently in the Role?', 'In the role as Acting?', 'Notes'], 'Data Types': 'ID                             int64\nAgency                        object\nRecord Group                   int64\nGAL LOOKUP - Display name     object\nGAL LOOKUP - Email Address    object\nAlias                         object\nName                          object\nRole                          object\nBeginning Date                object\nEnding Date                   object\nCurrently in the Role?        object\nIn the role as Acting?        object\nNotes                         object\ndtype: object', 'Sample': [{'ID': 1, 'Agency': 'AMS', 'Record Group': 136, 'GAL LOOKUP - Display name': 'Adams, Keith', 'GAL LOOKUP - Email Address': 'Keith.Adams@usda.gov ', 'Alias': 'Keith.Adams@ams.usda.gov', 'Name': 'Keith Adams', 'Role': 'Mission Area Senior Program Manager', 'Beginning Date': '3/16/2021', 'Ending Date': '1/20/2025', 'Currently in the Role?': 'Yes', 'In the role as Acting?': 'No', 'Notes': nan}, {'ID': 2, 'Agency': 'AMS', 'Record Group': 136, 'GAL LOOKUP - Display name': 'Adams, Keith', 'GAL LOOKUP - Email Address': 'Keith.Adams@usda.gov\n', 'Alias': 'Keith.Adams@ams.usda.gov', 'Name': 'Keith Adams', 'Role': 'Deputy Administrator, Management and Analysis Program', 'Beginning Date': '1/25/2021', 'Ending Date': '6/28/2024', 'Currently in the Role?': 'Yes', 'In the role as Acting?': 'No', 'Notes': nan}, {'ID': 3, 'Agency': 'AMS', 'Record Group': 136, 'GAL LOOKUP - Display name': 'Allen, William', 'GAL LOOKUP - Email Address': 'William.Allen@usda.gov', 'Alias': nan, 'Name': 'William D. Allen', 'Role': 'Director Legislative and Reguatory Review', 'Beginning Date': '9/27/2022', 'Ending Date': '1/20/2025', 'Currently in the Role?': 'Yes', 'In the role as Acting?': 'No', 'Notes': nan}, {'ID': 4, 'Agency': 'AMS', 'Record Group': 136, 'GAL LOOKUP - Display name': 'Alonzo, Anne', 'GAL LOOKUP - Email Address': 'Anne.Alonzo@ams.usda.gov', 'Alias': nan, 'Name': 'Anne Alonzo', 'Role': 'Administrator', 'Beginning Date': '9/27/2022', 'Ending Date': '1/20/2025', 'Currently in the Role?': 'No', 'In the role as Acting?': 'No', 'Notes': nan}, {'ID': 5, 'Agency': 'AMS', 'Record Group': 136, 'GAL LOOKUP - Display name': 'Bailey, Douglas', 'GAL LOOKUP - Email Address': 'Douglas.Bailey@ams.usda.gov', 'Alias': nan, 'Name': 'Douglas Bailey', 'Role': 'Deputy Administrator, Information Technology Service', 'Beginning Date': '5/1/2020', 'Ending Date': nan, 'Currently in the Role?': 'No', 'In the role as Acting?': 'No', 'Notes': nan}, {'ID': 6, 'Agency': 'AMS', 'Record Group': 136, 'GAL LOOKUP - Display name': 'Bailey, Melissa', 'GAL LOOKUP - Email Address': 'Melissa.Bailey@usda.gov', 'Alias': nan, 'Name': 'Melissa Bailey', 'Role': 'Associate Adminstrator', 'Beginning Date': '11/1/2017', 'Ending Date': nan, 'Currently in the Role?': 'Yes', 'In the role as Acting?': 'No', 'Notes': nan}, {'ID': 7, 'Agency': 'AMS', 'Record Group': 136, 'GAL LOOKUP - Display name': 'Barnes, Rex Allen', 'GAL LOOKUP - Email Address': 'Rex.Barnes@ams.usda.gov', 'Alias': nan, 'Name': 'Rex Barnes', 'Role': 'Deputy Administrator, Poultry Program', 'Beginning Date': '1/1/2016', 'Ending Date': nan, 'Currently in the Role?': 'No', 'In the role as Acting?': 'No', 'Notes': nan}, {'ID': 8, 'Agency': 'AMS', 'Record Group': 136, 'GAL LOOKUP - Display name': 'Barnes, Rex Allen', 'GAL LOOKUP - Email Address': 'Rex.Barnes@ams.usda.gov', 'Alias': nan, 'Name': 'Rex Barnes', 'Role': 'Associate Administrator', 'Beginning Date': '5/5/2013', 'Ending Date': '1/15/2016', 'Currently in the Role?': 'No', 'In the role as Acting?': 'No', 'Notes': nan}, {'ID': 9, 'Agency': 'AMS', 'Record Group': 136, 'GAL LOOKUP - Display name': 'Coale, Dana', 'GAL LOOKUP - Email Address': 'Dana.Coale@usda.gov', 'Alias': nan, 'Name': 'Dana Coale', 'Role': 'Dep ...

# %%
question = "What is the Starting and Ending date for Erin Morris"

prompt_template = '''
Assistant is an AI model that takes in a sample from a dataset, understands the data, and provides the answer to the question:  

**Question:** {question}  

### Instructions:  
- Analyze the given sample data to extract relevant insights.  
- Provide all the information which is being asked.  
- If the question asks for multiple pieces of information, include all relevant details.
- Alias is also Considered as the Email Address
- Appearing Same Email Address Twice doesnt considered as More than One Email

SCHEMA:
--------
{schema}

DATA TYPES: 
--------
{data_types}

SAMPLE: 
--------
{sample}
'''.format(question=question, schema=metadata["Schema"], data_types=metadata["Data Types"], sample=metadata["Sample"])

response = gpt4o.invoke(prompt_template)
response.content
# Out:
# 'For Erin Morris, the relevant details are as follows:\n\n- **Starting Date (Beginning Date):** 2/20/2020\n- **Ending Date:** (Currently in the role, so no ending date is provided)\n\nAdditionally, Erin Morris has held another role with the following details:\n- **Starting Date (Beginning Date):** 8/14/2011\n- **Ending Date:** 6/30/2013\n\nIn summary:\n- **Current Role:**\n  - **Starting Date:** 2/20/2020\n  - **Ending Date:** Currently in the role (no ending date)\n  \n- **Previous Role:**\n  - **Starting Date:** 8/14/2011\n  - **Ending Date:** 6/30/2013'

# %%
print("Question: ", question)
print("Answer: ", response.content)
# Out:
# Question:  What is the Starting and Ending date for Erin Morris
# Answer:  For Erin Morris, the relevant details are as follows:
#
# - **Starting Date (Beginning Date):** 2/20/2020
# - **Ending Date:** (Currently in the role, so no ending date is provided)
#
# Additionally, Erin Morris has held another role with the following details:
# - **Starting Date (Beginning Date):** 8/14/2011
# - **Ending Date:** 6/30/2013
#
# In summary:
# - **Current Role:**
#   - **Starting Date:** 2/20/2020
#   - **Ending Date:** Currently in the role (no ending date)
#
# - **Previous Role:**
#   - **Starting Date:** 8/14/2011
#   - **Ending Date:** 6/30/2013

# %%
metadata["Sample"]
# Out:
# [{'ID': 1,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Adams, Keith',
#   'GAL LOOKUP - Email Address': 'Keith.Adams@usda.gov ',
#   'Alias': 'Keith.Adams@ams.usda.gov',
#   'Name': 'Keith Adams',
#   'Role': 'Mission Area Senior Program Manager',
#   'Beginning Date': '3/16/2021',
#   'Ending Date': '1/20/2025',
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 2,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Adams, Keith',
#   'GAL LOOKUP - Email Address': 'Keith.Adams@usda.gov\n',
#   'Alias': 'Keith.Adams@ams.usda.gov',
#   'Name': 'Keith Adams',
#   'Role': 'Deputy Administrator, Management and Analysis Program',
#   'Beginning Date': '1/25/2021',
#   'Ending Date': '6/28/2024',
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 3,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Allen, William',
#   'GAL LOOKUP - Email Address': 'William.Allen@usda.gov',
#   'Alias': nan,
#   'Name': 'William D. Allen',
#   'Role': 'Director Legislative and Reguatory Review',
#   'Beginning Date': '9/27/2022',
#   'Ending Date': '1/20/2025',
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 4,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Alonzo, Anne',
#   'GAL LOOKUP - Email Address': 'Anne.Alonzo@ams.usda.gov',
#   'Alias': nan,
#   'Name': 'Anne Alonzo',
#   'Role': 'Administrator',
#   'Beginning Date': '9/27/2022',
#   'Ending Date': '1/20/2025',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 5,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Bailey, Douglas',
#   'GAL LOOKUP - Email Address': 'Douglas.Bailey@ams.usda.gov',
#   'Alias': nan,
#   'Name': 'Douglas Bailey',
#   'Role': 'Deputy Administrator, Information Technology Service',
#   'Beginning Date': '5/1/2020',
#   'Ending Date': nan,
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 6,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Bailey, Melissa',
#   'GAL LOOKUP - Email Address': 'Melissa.Bailey@usda.gov',
#   'Alias': nan,
#   'Name': 'Melissa Bailey',
#   'Role': 'Associate Adminstrator',
#   'Beginning Date': '11/1/2017',
#   'Ending Date': nan,
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 7,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Barnes, Rex Allen',
#   'GAL LOOKUP - Email Address': 'Rex.Barnes@ams.usda.gov',
#   'Alias': nan,
#   'Name': 'Rex Barnes',
#   'Role': 'Deputy Administrator, Poultry Program',
#   'Beginning Date': '1/1/2016',
#   'Ending Date': nan,
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 8,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Barnes, Rex Allen',
#   'GAL LOOKUP - Email Address': 'Rex.Barnes@ams.usda.gov',
#   'Alias': nan,
#   'Name': 'Rex Barnes',
#   'Role': 'Associate Administrator',
#   'Beginning Date': '5/5/2013',
#   'Ending Date': '1/15/2016',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 9,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Coale, Dana',
#   'GAL LOOKUP - Email Address': 'Dana.Coale@usda.gov',
#   'Alias': nan,
#   'Name': 'Dana Coale',
#   'Role': 'Deputy Administrator, Dairy Program',
#   'Beginning Date': '10/12/2008',
#   'Ending Date': '1/2/2017',
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 10,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Densel, Brock',
#   'GAL LOOKUP - Email Address': 'Brock.Densel@usda.gov',
#   'Alias': nan,
#   'Name': 'Brock Densel',
#   'Role': 'Chief of Staff',
#   'Beginning Date': '4/25/2021',
#   'Ending Date': nan,
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 11,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Dudley, Judith',
#   'GAL LOOKUP - Email Address': 'Judith.Dudley@ams.usda.gov',
#   'Alias': nan,
#   'Name': 'Judith Dudley',
#   'Role': 'Information Technology Service, Deputy Administrator',
#   'Beginning Date': '9/2/2007',
#   'Ending Date': '8/24/2012',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 12,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Durando, Michael',
#   'GAL LOOKUP - Email Address': 'Michael.Durando@ams.usda.gov',
#   'Alias': nan,
#   'Name': 'Mike Durando',
#   'Role': 'Fair Trade Practices Program, Deputy Administrator',
#   'Beginning Date': '8/25/2012',
#   'Ending Date': '1/2/2016',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 13,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Earnest, Darryl',
#   'GAL LOOKUP - Email Address': 'Darryl.earnest@usda.gov',
#   'Alias': nan,
#   'Name': 'Darryl Earnest',
#   'Role': 'Cotton and Tobacco Program, Deputy Administrator',
#   'Beginning Date': '9/5/2004',
#   'Ending Date': nan,
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 14,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Eckhouse, Sara',
#   'GAL LOOKUP - Email Address': 'sara.eckhouse@osec.usda.gov',
#   'Alias': nan,
#   'Name': 'Sara Eckhouse',
#   'Role': 'Chief of Staff',
#   'Beginning Date': '8/30/2020',
#   'Ending Date': '1/20/2021',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 15,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Epstein, Robert',
#   'GAL LOOKUP - Email Address': 'robert.epstein@ams.usda.gov',
#   'Alias': nan,
#   'Name': 'Robert Epstein',
#   'Role': 'Deputy Administrator, Science and Technology',
#   'Beginning Date': '1/1/2015',
#   'Ending Date': '12/31/2018',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 16,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Garrigus, Ashley',
#   'GAL LOOKUP - Email Address': 'Ashley.Garrigus@usda.gov',
#   'Alias': nan,
#   'Name': 'Ashley Garrigus',
#   'Role': 'Director of Public Affairs',
#   'Beginning Date': '3/31/2019',
#   'Ending Date': '1/3/2021',
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 17,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Gilchrist, Clifton',
#   'GAL LOOKUP - Email Address': 'Clifton.Gilchrist@usda.gov',
#   'Alias': nan,
#   'Name': 'Clifton Gilcrest',
#   'Role': 'Director of Civil Rights',
#   'Beginning Date': '5/15/2005',
#   'Ending Date': nan,
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 18,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Glasgow, David',
#   'GAL LOOKUP - Email Address': 'David.Glasgow@usda.gov',
#   'Alias': nan,
#   'Name': 'David Glasgow',
#   'Role': 'Director of Public Affairs',
#   'Beginning Date': '2/12/2012',
#   'Ending Date': '5/14/2016',
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 19,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Guo, Ruihong',
#   'GAL LOOKUP - Email Address': 'Ruihong.guo@usda.gov',
#   'Alias': nan,
#   'Name': 'Ruihong Guo',
#   'Role': 'Associate Administrator, COO',
#   'Beginning Date': '8/27/2000',
#   'Ending Date': '6/30/2013',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 20,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Guo, Ruihong',
#   'GAL LOOKUP - Email Address': 'Ruihong.guo@usda.gov',
#   'Alias': nan,
#   'Name': 'Ruihong Guo',
#   'Role': 'Science and Technology Program Deputy Administrator',
#   'Beginning Date': '12/1/2019',
#   'Ending Date': nan,
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 21,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Hughes, Darrell A - AMS',
#   'GAL LOOKUP - Email Address': 'Darrell.A.Hughes@usda.gov',
#   'Alias': nan,
#   'Name': 'Darrell Hughes',
#   'Role': 'Chief of Staff',
#   'Beginning Date': '3/15/2009',
#   'Ending Date': nan,
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 22,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Jimenez, Sonia',
#   'GAL LOOKUP - Email Address': 'Sonia.Jimenez@usda.gov',
#   'Alias': nan,
#   'Name': 'Sonia Jimenez',
#   'Role': 'Deputy Associate Administrator',
#   'Beginning Date': '1/1/2017',
#   'Ending Date': nan,
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'Yes',
#   'Notes': nan},
#  {'ID': 23,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Jimenez, Sonia',
#   'GAL LOOKUP - Email Address': 'Sonia.Jimenez@usda.gov',
#   'Alias': nan,
#   'Name': 'Sonia Jimenez',
#   'Role': 'Deputy Administrator, Management',
#   'Beginning Date': '11/6/2011',
#   'Ending Date': '9/7/2013',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 24,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Jimenez, Sonia',
#   'GAL LOOKUP - Email Address': 'Sonia.Jimenez@usda.gov',
#   'Alias': nan,
#   'Name': 'Sonia Jimenez',
#   'Role': 'Deputy Administrator, Specialty Crops Program',
#   'Beginning Date': '7/8/2018',
#   'Ending Date': nan,
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 25,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Jones, Randall',
#   'GAL LOOKUP - Email Address': 'Randall.D.Jones@usda.gov',
#   'Alias': 'Randall.D.Jones@ams.usda.gov',
#   'Name': 'Randall D. Jones',
#   'Role': 'Deputy Administrator, GIPSA',
#   'Beginning Date': '1/6/2019',
#   'Ending Date': nan,
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 26,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Jones, Randall',
#   'GAL LOOKUP - Email Address': 'Randall.D.Jones@usda.gov',
#   'Alias': nan,
#   'Name': 'Randall D. Jones',
#   'Role': 'Associate Administrator, COO',
#   'Beginning Date': '1/1/2013',
#   'Ending Date': '12/31/2016',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 27,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Jones, Randall',
#   'GAL LOOKUP - Email Address': 'Randall.D.Jones@usda.gov',
#   'Alias': nan,
#   'Name': 'Randall D. Jones',
#   'Role': 'Deputy Administrator, Fair Trade Practices Program',
#   'Beginning Date': '9/7/2014',
#   'Ending Date': '9/16/2017',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 28,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Keeney, Robert',
#   'GAL LOOKUP - Email Address': 'Robert.Keeney@ams.usda.gov',
#   'Alias': nan,
#   'Name': 'Robert Keeney',
#   'Role': 'Deputy Administrator, Fruit and Vegetable',
#   'Beginning Date': '9/17/2017',
#   'Ending Date': nan,
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 29,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'King, Ellen',
#   'GAL LOOKUP - Email Address': 'ellen.king@ams.usda.gov',
#   'Alias': nan,
#   'Name': 'Ellen King',
#   'Role': 'Associate Administrator, COO',
#   'Beginning Date': '7/20/2008',
#   'Ending Date': '11/25/2017',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 30,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Kovacs, Tricia',
#   'GAL LOOKUP - Email Address': 'Tricia.Kovacs@usda.gov',
#   'Alias': nan,
#   'Name': 'Patricia Kovacs',
#   'Role': 'Local and Regional Food Systems Policy Advisor',
#   'Beginning Date': '11/26/2017',
#   'Ending Date': '6/30/2020',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 31,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Kovacs, Tricia',
#   'GAL LOOKUP - Email Address': 'Tricia.Kovacs@usda.gov',
#   'Alias': nan,
#   'Name': 'Patricia Kovacs',
#   'Role': 'Associate Deputy Administrator',
#   'Beginning Date': '11/26/2017',
#   'Ending Date': '6/30/2020',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'Yes',
#   'Notes': nan},
#  {'ID': 32,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Kovacs, Tricia',
#   'GAL LOOKUP - Email Address': 'Tricia.Kovacs@usda.gov',
#   'Alias': nan,
#   'Name': 'Patricia Kovacs',
#   'Role': 'Transportation and Marketing Program, Deputy Administrator',
#   'Beginning Date': '1/7/1996',
#   'Ending Date': '10/6/2012',
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 33,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'McCullough, Cathie E',
#   'GAL LOOKUP - Email Address': 'cathie.mccullough@ams.usda.gov',
#   'Alias': nan,
#   'Name': 'Catherine McCullough',
#   'Role': 'Compliance and Analysis Program, Deputy Administrator',
#   'Beginning Date': '3/27/2011',
#   'Ending Date': '11/3/2011',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 34,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'McEvoy, Miles',
#   'GAL LOOKUP - Email Address': 'miles.mcevoy@ams.usda.gov',
#   'Alias': nan,
#   'Name': 'Miles McEvoy',
#   'Role': 'National Organic Program, Deputy Administrator',
#   'Beginning Date': '8/1/2016',
#   'Ending Date': '1/1/2020',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 35,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Morris, Craig',
#   'GAL LOOKUP - Email Address': 'Craig.Morris@usda.gov',
#   'Alias': 'Craig.Morris@ams.usda.gov',
#   'Name': 'Craig Morris',
#   'Role': 'Livestock, Poultry and Seed, Depurty Administrator',
#   'Beginning Date': '4/1/2019',
#   'Ending Date': '1/1/2020',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 36,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Morris, Erin',
#   'GAL LOOKUP - Email Address': 'Erin.Morris@usda.gov',
#   'Alias': nan,
#   'Name': 'Erin Morris',
#   'Role': 'Associate Administrator, COO',
#   'Beginning Date': '2/20/2020',
#   'Ending Date': nan,
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 37,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Morris, Erin',
#   'GAL LOOKUP - Email Address': 'Erin.Morris@usda.gov',
#   'Alias': 'Erin.Morris@ams.usda.gov',
#   'Name': 'Erin Morris',
#   'Role': 'Associate Administrator',
#   'Beginning Date': '8/14/2011',
#   'Ending Date': '6/30/2013',
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 38,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Nash, Douglas',
#   'GAL LOOKUP - Email Address': 'Douglas.Nash@usda.gov',
#   'Alias': nan,
#   'Name': 'Douglas Nash',
#   'Role': 'Deputy Administrator, IT Services',
#   'Beginning Date': '11/8/2009',
#   'Ending Date': '9/30/2017',
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 39,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Neal, Arthur',
#   'GAL LOOKUP - Email Address': 'Arthur.Neal@usda.gov',
#   'Alias': nan,
#   'Name': 'Arthur Neal',
#   'Role': 'Transportation and Marketing Program, Deputy Administrator',
#   'Beginning Date': '5/27/2007',
#   'Ending Date': '10/28/2017',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 40,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Neal, Arthur',
#   'GAL LOOKUP - Email Address': 'Arthur.Neal@usda.gov',
#   'Alias': nan,
#   'Name': 'Arthur Neal',
#   'Role': 'Federal Grain Inspection Service Program, Deputy Administrator',
#   'Beginning Date': '5/18/2014',
#   'Ending Date': nan,
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 41,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': "O'Hagan, Christopher",
#   'GAL LOOKUP - Email Address': 'Christopher.Ohagan@usda.gov',
#   'Alias': nan,
#   'Name': "Christopher O'Hagan",
#   'Role': 'Special Assistant',
#   'Beginning Date': '9/16/2018',
#   'Ending Date': nan,
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 42,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Osterlind, Anna',
#   'GAL LOOKUP - Email Address': 'Anna.Osterlind@usda.gov',
#   'Alias': nan,
#   'Name': 'Anna Osterlind',
#   'Role': 'Chief of Staff',
#   'Beginning Date': '9/3/2017',
#   'Ending Date': nan,
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 43,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Parrott, Charles',
#   'GAL LOOKUP - Email Address': 'charles.parrott@usda.gov',
#   'Alias': nan,
#   'Name': 'Charles Parrott',
#   'Role': 'Deputy Administrator, Fruit and Vegetable',
#   'Beginning Date': '3/27/2011',
#   'Ending Date': '2/16/2019',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 44,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Porter, Jennifer',
#   'GAL LOOKUP - Email Address': 'Jennifer.Porter@usda.gov',
#   'Alias': nan,
#   'Name': 'Jennifer Porter',
#   'Role': 'Livestock & Poutry Program, Deputy Administrator',
#   'Beginning Date': '2/17/2019',
#   'Ending Date': nan,
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 45,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Shipman, David R',
#   'GAL LOOKUP - Email Address': 'David.Shipman@ams.usda.gov',
#   'Alias': nan,
#   'Name': 'David Shipman',
#   'Role': 'Administrator',
#   'Beginning Date': nan,
#   'Ending Date': '10/2/2020',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 46,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Shipman, David R',
#   'GAL LOOKUP - Email Address': 'David.Shipman@ams.usda.gov',
#   'Alias': nan,
#   'Name': 'David Shipman',
#   'Role': 'Associate Administrator',
#   'Beginning Date': '8/4/2019',
#   'Ending Date': nan,
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 47,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Starmer, Elanor',
#   'GAL LOOKUP - Email Address': 'Elanor.Starmer@ams.usda.gov',
#   'Alias': nan,
#   'Name': 'Elanor Starmer',
#   'Role': 'Administrator',
#   'Beginning Date': '10/21/2012',
#   'Ending Date': '4/29/2017',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 48,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Stewart, Dana - AMS',
#   'GAL LOOKUP - Email Address': 'Dana.Stewart@usda.gov',
#   'Alias': nan,
#   'Name': 'Dana Blatt Stewart',
#   'Role': 'Chief of Staff',
#   'Beginning Date': '9/2/2018',
#   'Ending Date': nan,
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 49,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Summers, Bruce',
#   'GAL LOOKUP - Email Address': 'Bruce.Summers@usda.gov',
#   'Alias': 'Bruce.Summers@ams.usda.gov',
#   'Name': 'Bruce Summers',
#   'Role': 'Administrator',
#   'Beginning Date': '4/13/2008',
#   'Ending Date': '6/1/2013',
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'Yes',
#   'Notes': nan},
#  {'ID': 50,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Summers, Bruce',
#   'GAL LOOKUP - Email Address': 'Bruce.Summers@usda.gov',
#   'Alias': 'Bruce.Summers@ams.usda.gov',
#   'Name': 'Bruce Summers',
#   'Role': 'Associate Administrator',
#   'Beginning Date': '4/13/2008',
#   'Ending Date': '6/1/2013',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 51,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Theriot, Luke',
#   'GAL LOOKUP - Email Address': 'Luke.Theriot@usda.gov',
#   'Alias': nan,
#   'Name': 'Luke Theriot',
#   'Role': 'Chief of Staff',
#   'Beginning Date': '3/20/2016',
#   'Ending Date': '1/20/2017',
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 52,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Thompson Pegg, Rayne',
#   'GAL LOOKUP - Email Address': 'rayne.pegg@ams.usda.gov',
#   'Alias': nan,
#   'Name': 'Rayne Thompson Pegg',
#   'Role': 'Administrator',
#   'Beginning Date': '10/29/2015',
#   'Ending Date': nan,
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 53,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Tucker, Jennifer',
#   'GAL LOOKUP - Email Address': 'Jennifer.Tucker@usda.gov',
#   'Alias': nan,
#   'Name': 'Jennifer Tucker',
#   'Role': 'National Organic Program, Deputy Administrator',
#   'Beginning Date': '10/30/2016',
#   'Ending Date': nan,
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 54,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Tuckwiller, David',
#   'GAL LOOKUP - Email Address': 'David.Tuckwiller@usda.gov',
#   'Alias': 'David.Tuckwiller@ams.usda.gov',
#   'Name': 'David Tuckwiller',
#   'Role': 'Director of Commodity and Procurement',
#   'Beginning Date': '10/30/2016',
#   'Ending Date': '1/19/2017',
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 55,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Tuckwiller, David - AMS',
#   'GAL LOOKUP - Email Address': 'David.Tuckwiller@usda.gov',
#   'Alias': 'David.Tuckwiller@ams.usda.gov',
#   'Name': 'Jack David Tuckwiller',
#   'Role': 'Deputy Administrator, Commodity and Procurement',
#   'Beginning Date': nan,
#   'Ending Date': '4/8/2023',
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 56,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': 'Walker, Lorren',
#   'GAL LOOKUP - Email Address': 'Lorren.Walker@usda.gov',
#   'Alias': 'Lorren.Walker@ams.usda.gov',
#   'Name': 'Lorren Walker',
#   'Role': 'Chief of Staff',
#   'Beginning Date': '7/5/2009',
#   'Ending Date': '7/15/2011',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 57,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Director of Civil Rights',
#   'Beginning Date': '6/24/2018',
#   'Ending Date': nan,
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 58,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Deputy Administrator, Cotton and Tobacco Program',
#   'Beginning Date': '9/2/2018',
#   'Ending Date': nan,
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 59,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Deputy Administrator, Federal Grain Inspection Service Program',
#   'Beginning Date': '9/28/2018',
#   'Ending Date': nan,
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 60,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Deputy Administrator, Livestock & Poutry Program',
#   'Beginning Date': '6/4/2018',
#   'Ending Date': nan,
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 61,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Deputy Administrator, National Organic Program',
#   'Beginning Date': nan,
#   'Ending Date': nan,
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 62,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Deputy Administrator, Science and Technology Program',
#   'Beginning Date': nan,
#   'Ending Date': nan,
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 63,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Deputy Administrator, Transportation and Marketing Program',
#   'Beginning Date': nan,
#   'Ending Date': nan,
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 64,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Director of Legislative and Regulatory Review',
#   'Beginning Date': nan,
#   'Ending Date': nan,
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 65,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Administrator of the Agricultural Marketing Agency',
#   'Beginning Date': nan,
#   'Ending Date': nan,
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 66,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Chief of Staff, Office of the Administrator (GIPSA)',
#   'Beginning Date': nan,
#   'Ending Date': nan,
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 67,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Regional Director, Western Region (GIPSA)',
#   'Beginning Date': nan,
#   'Ending Date': nan,
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 68,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Regional Director, Midwestern Region (GIPSA)',
#   'Beginning Date': nan,
#   'Ending Date': nan,
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 69,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Regional Director, Eastern Region (GIPSA)',
#   'Beginning Date': nan,
#   'Ending Date': nan,
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 70,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Chief Information Officer and Business Director, Information Technology Staff (GIPSA)',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2017',
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 71,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Deputy Administrator, Federal Grain Inspection Service (GIPSA)',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2017',
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 72,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Deputy Administrator, Packers and Stockyards Programs (GIPSA)',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2017',
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 73,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Administrator of the Federal Grain Inspection Service (GIPSA)',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2017',
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 74,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Director, Management and Budget Services (GIPSA)',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2017',
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 75,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Director, Technology and Sciences Division (GIPSA)',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2017',
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 76,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Director, Litigation and Economic Analysis Division (GIPSA)',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2017',
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 77,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Director, Quality Assurance and Compliance Division (GIPSA)',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2017',
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 78,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Director, Field Management Division (GIPSA)',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2017',
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 79,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Deputy Administrator, Compliance and Analysis Program',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2017',
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 80,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Deputy Administrator, Compliance and Analysis Program',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2017',
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 81,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Deputy Administrator, Management and Analysis Program',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2017',
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 82,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Deputy Administrator, Management and Analysis Program',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2017',
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 83,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Deputy Administrator, Information Technology Services',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2018',
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 84,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Deputy Administrator, Information Technology Services',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2018',
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 85,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Budget Officer',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2018',
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 86,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': nan,
#   'Role': 'Budget Officer',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2018',
#   'Currently in the Role?': nan,
#   'In the role as Acting?': nan,
#   'Notes': nan},
#  {'ID': 87,
#   'Agency': 'AMS',
#   'Record Group': 136,
#   'GAL LOOKUP - Display name': nan,
#   'GAL LOOKUP - Email Address': nan,
#   'Alias': nan,
#   'Name': 'Lawrence "Larry" Mitchell',
#   'Role': 'Administrator, MRP-Grain Inspection, Packers and Stockyards (GIPSA)',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2020',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 88,
#   'Agency': 'APHIS',
#   'Record Group': 463,
#   'GAL LOOKUP - Display name': 'Bech, Rebecca A - APHIS',
#   'GAL LOOKUP - Email Address': 'rebecca.a.bech@usda.gov',
#   'Alias': nan,
#   'Name': 'Rebecca Bech',
#   'Role': 'Deputy Administrator, Plant Protection and Quarantine',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2020',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 89,
#   'Agency': 'APHIS',
#   'Record Group': 463,
#   'GAL LOOKUP - Display name': 'Bech, Rebecca A - APHIS',
#   'GAL LOOKUP - Email Address': 'rebecca.a.bech@usda.gov',
#   'Alias': nan,
#   'Name': 'Rebecca Bech',
#   'Role': 'Regional Director, Eastern Division, Plant Protection and Quarantine',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2021',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 90,
#   'Agency': 'APHIS',
#   'Record Group': 463,
#   'GAL LOOKUP - Display name': 'Bennett, Steven M',
#   'GAL LOOKUP - Email Address': 'steven.m.bennett@usda.gov',
#   'Alias': nan,
#   'Name': 'Steven M. Bennett',
#   'Role': 'Director, Investigative and Enforcement Services',
#   'Beginning Date': nan,
#   'Ending Date': '12/31/2021',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 91,
#   'Agency': 'APHIS',
#   'Record Group': 463,
#   'GAL LOOKUP - Display name': 'Blakely, Cheryle L - APHIS',
#   'GAL LOOKUP - Email Address': 'cheryle.l.blakely@usda.gov',
#   'Alias': nan,
#   'Name': 'Cheryle Blakely',
#   'Role': 'Associate Deputy Administrator, International Services',
#   'Beginning Date': '1/20/2009',
#   'Ending Date': '1/20/2017',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 92,
#   'Agency': 'APHIS',
#   'Record Group': 463,
#   'GAL LOOKUP - Display name': 'Blakely, Cheryle L - APHIS',
#   'GAL LOOKUP - Email Address': 'cheryle.l.blakely@usda.gov',
#   'Alias': nan,
#   'Name': 'Cheryle Blakely',
#   'Role': 'Deputy Administrator, International Services',
#   'Beginning Date': '1/6/2008',
#   'Ending Date': '7/13/2013',
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': '\xa0No',
#   'Notes': nan},
#  {'ID': 93,
#   'Agency': 'APHIS',
#   'Record Group': 463,
#   'GAL LOOKUP - Display name': 'BOHMAN, MARY E',
#   'GAL LOOKUP - Email Address': 'mary.bohman@usda.gov',
#   'Alias': nan,
#   'Name': 'Mary Bohman',
#   'Role': 'Associate Administrator',
#   'Beginning Date': '7/14/2013',
#   'Ending Date': '11/14/2015',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 94,
#   'Agency': 'APHIS',
#   'Record Group': 463,
#   'GAL LOOKUP - Display name': 'Brown, Charles',
#   'GAL LOOKUP - Email Address': 'charles.s.brown@aphis.usda.gov',
#   'Alias': nan,
#   'Name': 'Charles Brown',
#   'Role': 'Director, Eastern Region',
#   'Beginning Date': '8/7/2016',
#   'Ending Date': '12/19/2020',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': '\xa0No',
#   'Notes': nan},
#  {'ID': 95,
#   'Agency': 'APHIS',
#   'Record Group': 463,
#   'GAL LOOKUP - Display name': 'Bucknall, Janet L - APHIS',
#   'GAL LOOKUP - Email Address': 'janet.l.bucknall@usda.gov',
#   'Alias': nan,
#   'Name': 'Janet Bucknall',
#   'Role': 'Associate Deputy Administrator, BRS',
#   'Beginning Date': '12/30/2012',
#   'Ending Date': '2/3/2018',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 96,
#   'Agency': 'APHIS',
#   'Record Group': 463,
#   'GAL LOOKUP - Display name': 'Bucknall, Janet L - APHIS',
#   'GAL LOOKUP - Email Address': 'janet.l.bucknall@usda.gov',
#   'Alias': nan,
#   'Name': 'Janet Bucknall',
#   'Role': 'Regional Director, Eastern Division, Wildlife Services',
#   'Beginning Date': '2/4/2018',
#   'Ending Date': nan,
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 97,
#   'Agency': 'APHIS',
#   'Record Group': 463,
#   'GAL LOOKUP - Display name': 'Bucknall, Janet L - APHIS',
#   'GAL LOOKUP - Email Address': 'janet.l.bucknall@usda.gov',
#   'Alias': nan,
#   'Name': 'Janet Bucknall',
#   'Role': 'Deputy Administrator, Wildlife Services',
#   'Beginning Date': '9/2/2018',
#   'Ending Date': '3/16/2019',
#   'Currently in the Role?': 'Yes',
#   'In the role as Acting?': '\xa0No',
#   'Notes': nan},
#  {'ID': 98,
#   'Agency': 'APHIS',
#   'Record Group': 463,
#   'GAL LOOKUP - Display name': 'Clay, William H -APHIS',
#   'GAL LOOKUP - Email Address': 'bill.clay@aphis.usda.gov',
#   'Alias': nan,
#   'Name': 'William Clay',
#   'Role': 'Deputy Administrator, Wildlife Services (Retired)',
#   'Beginning Date': '12/29/2002',
#   'Ending Date': '2/22/2014',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 99,
#   'Agency': 'APHIS',
#   'Record Group': 463,
#   'GAL LOOKUP - Display name': 'Clay, William H -APHIS',
#   'GAL LOOKUP - Email Address': 'william.h.clay@aphis.usda.gov',
#   'Alias': nan,
#   'Name': 'William Clay',
#   'Role': 'Deputy Administrator, Wildlife Services (Retired)',
#   'Beginning Date': '4/6/2014',
#   'Ending Date': '7/9/2016',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan},
#  {'ID': 100,
#   'Agency': 'APHIS',
#   'Record Group': 463,
#   'GAL LOOKUP - Display name': 'Clifford, John',
#   'GAL LOOKUP - Email Address': 'john.clifford@aphis.usda.gov',
#   'Alias': nan,
#   'Name': 'John Clifford',
#   'Role': 'Deputy Administrator, Veterinary Services and Chief Veterinary Officer',
#   'Beginning Date': '7/10/2016',
#   'Ending Date': '2/3/2018',
#   'Currently in the Role?': 'No',
#   'In the role as Acting?': 'No',
#   'Notes': nan}]
